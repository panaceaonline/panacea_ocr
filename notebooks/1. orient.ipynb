# %%
from IPython.display import Image

imgs = '1-iznachalnyj-vid-cheka.png'
imgs = '/home/rustam/Pictures/med/rotate/221.jpeg'

Image(filename=imgs)

# %%
from alyn import SkewDetect
sd = SkewDetect(
	input_file=imgs,
	batch_path='./',
	output_file='./out.txt',
	display_output='Yes')
sd.run()
# Out:
# Image File: /home/rustam/Pictures/med/rotate/221.jpeg
# Angle bins: [[], [64.860335195530723, 64.860335195530723, 64.860335195530723, 64.860335195530723, 64.860335195530723], [-24.636871508379887, -24.636871508379887], []]
# Estimated Angle: 64.8603351955
# Average Deviation from pi/4: 20.1745810056

# %%
from alyn import Deskew
d = Deskew(
	input_file=imgs,
	display_image='preview the image on screen',
	output_file='/home/rustam/Pictures/med/1.rotated.jpg',
	r_angle=0
)
d.run()
